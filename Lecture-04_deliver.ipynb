# %% [markdown]
# # AM10 - Module: Basics
#
# ## Lecture 04

# %% [markdown]
# ### Learning objectives:
#
# 1. Plotting as a tool to visualize functional behavior
#
# 2. Definition of functions.
#
# 3. Special functions:
#
#     - Step function (Heaviside) $\theta(x)$
#
#     - Delta function (Dirac) $\delta(x)$

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. PLOTS
#
# One of the biggest joys of using computing is to plot various math object
#
# This can actually be extremely helpful in gaining a better understanding.
#
#
# In the example below, a simple plot helps us understand that there is a pole (an infinity) at the value x=0.

# %%
xmin=-5.0
xmax=5.0
Nx=100
x=np.linspace(xmin,xmax,Nx)
f=1/x
plt.plot(x,f,'b-')

# %% [markdown]
# #### Now figure out a way to eliminate the artificial line connecting plus infinity and minus infinity
#
# Find the position of the maximum of the function and the position of the minimum of the function and slice the array to two parts, then plot each part separately

# %% [markdown]
# ## 2. FUNCTION DEFINITION
#
# A very powerful tool is the definition of our own functions, which take some arguments and give back some value, just like functions of real variables.
#
# Functions are defined with the `def` keyword, and a series of arguments are specified in parentheses after the function name. The `return` keyword ends execution of code at a certain point in the function, and returns value to the function's caller.

# %% [markdown]
# ### The $\theta$ function
#
# To do this properly, show plots first, of the $\theta(x-x_0)$ function itself for different values of $x_0$, then another function $f(x)$ and finally the product $\theta(x-x_0) f(x)$.
#
# Without this explanation it becomes very difficult to grasp

# %% [markdown]
# ### The normalized gaussian
#
# Position of the peak: $x=x_0$
#
# Width (standard deviation): $\sigma$
#
# $$g(x;x_0,\sigma) = \frac{1}{\sqrt{2 \pi} \sigma} e^{-(x-x_0)^2/2\sigma^2}$$
#
# Plot the normalized gaussian in the range $[-3 \sigma, 3 \sigma]$ around the peak value $x=x_0$.
