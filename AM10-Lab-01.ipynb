# %% [markdown]
# # Applied Math 10: Computing for Science and Engineering
#
# ## LAB-01 : Numbers in computers
#
# **Fall 2020**
#
# ---

# %% [markdown]
# ### Learning objectives:
#
# To be able to handle python syntax and built-in functions, variables and simple numerical operations, including addition, multiplication, division, roots, powers, exponentiation, logarithms, and trigonometric functions. Also, to be able to generate arrays with desired properties using the `numpy` library.

# %% [markdown]
# ### Structure of the Lab
# Labs are designed as hands-on activities, in class, comprising examples and exercises that we will go through during the Lab time. Team activities will enable you to discuss solution approaches and possible problems and challenges with your team members. The Lab encourages you to collaborate with your peers, team members, and the teaching staff in achieving the learning goals.
#
# ### Learning Goals of this Lab
#
# By the end of this Lab, you will have learned:
# - The basics of python programming, with emphasis on numerical applications
# - Importing and using the `numpy` module for basic numerical calculations
# - Generating `numpy` arrays with specified properties

# %% [markdown]
# ### Review of basic built-in python syntax and functions
#
# As [Wikipedia puts it](https://en.wikipedia.org/wiki/Python_(programming_language)), Python is an interpreted, high-level, general-purpose programming language. Python compels its user to follow a distinct style emphasizing code readability. The most apparent example is the use of whitespace indentation instead of brackets, braces, or heavy use of punctuation marks. It is a style that slowly grows on you. So, if you feel constrained by it, give Python a chance and you most likely will start enjoying it. Afterall, Python is the worlds most popular programming language [according to GitHub](http://pypl.github.io/PYPL.html).
#
# Being an open-source language it is being made more and more useful through all the immensity of libraries and modules that extend its functionality way beyond what comes built-in. Using these modules is often as easy as typing `import <module_name>`.

# %% [markdown]
# #### Python's basic data types
#
# Basic data types in python include:
#
# - Boolean (bool)
#     - example: True, False <br> <br>
#
# - Integer (int)
#     - example: 2020 <br> <br>
#
# - Floating point (float)
#     - example: 32.56, 4.5e2 <br> <br>
#
# - Text string (str)
#     - example: "I", 'love', '''Boston'''  <br> <br>
#
# - List (list)
#     - example: ['Efthimios', 'Eleni', 'Salma', 'Nishant', 'Robert', 'George', '2020'] <br> <br>
#  ***Note*** about arrays: python lists can contain values corresponding to different data types; <br>
#     arrays in python can only contain values corresponding to same data type. <br>
#     In AM10, we will work mainly with arrays as we will solve scientific and engineering problmes (which involve numbers only)
#     <br> <br>
#
# - Tuple (tuple)
#     - example: (1,2,3,4) ; Note: tuples are immutable   <br> <br>

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# #### 1.1 Forced Indentation
# Python forces a certain style of programming that is driven by using whitespace indentation instead of using brackets. You can use spaces or tabs for indentation depending on your personal preference. As a consequence, Python code generally looks more organized. Run the cell below and see the results. How do you fix the problem?

# %%
print("Hello, World!")
    print("Goodbye, World!")
# Out:
#   File "<ipython-input-1-f415ffdbbfe2>", line 2
#     print("Goodbye, World!")
#     ^
# IndentationError: unexpected indent

# %%
print("Hello, World!")
print("Goodbye, World!")
# Out:
# Hello, World!
# Goodbye, World!

# %% [markdown]
# #### 1.2 Variables
# Nearly always the first step in any numerical calculation is to create variables and assign values to them.

# %%
# Assigning strings to variables

x = "Hello"
y = "World"
print(x)
print(y)
print(x, y)
print(x, y, "!")
print(x, y + "!")
# Out:
# Hello
# World
# Hello World
# Hello World !
# Hello World!

# %%
# Assigning numeric values to variables

x = 10  # integers
y = float(x / 2)  # converting to float
z =  complex(x, y)  # complex numbers: x = real part, y = imaginary part
print(x, y, z)
# Out:
# 10 5.0 (10+5j)

# %%
z = 10 + 5.0j  # alternate way to assign complex numbers
print(z)
# Out:
# (10+5j)

# %%
# Single line, multiple assignments

x, y, z = 5, 9, 30.0
print(x, y, z)
# Out:
# 5 9 30.0

# %% [markdown]
# **Naming variables in python**
#
# The rules:
#
# - You can use lowercase letters (a through z)
# - You can use UPPERCASE letters (A through Z)
# - You can use digits (0 through 9)
# - You can use the underscore (_)
# - Names are case sensitive (boston, Boston, and BOSTON are different names)
# - Names must begin with a letter or an underscore, not a digit
# - Names that begin with an underscore are treated specially
# - Names cannot be one of python's reserved words.

# %% [markdown]
# Python reserves some names to be keywords and using these reserved keywords as variable names will result in Exceptions. Run the cell below to list all the reserved keywords.

# %%
from keyword import kwlist
print(kwlist)

# %% [markdown]
# #### Variables: Logical variables
#
# To compare different quantities, it is useful to have a logical variable, which can be "True" or "False".  This is a 1-bit variable. We can use it to decide what to do next, depending on whether something is true or false.  This is the "if/else" statement
#
# A very helpful operation is to check is one variable is ${\bf identically}$ equal to another one, denoted by "==".

# %%
b=True
print(b)
# Out:
# True

# %%
c=False
print(c)
# Out:
# False

# %%
d=(b==c)
print(d)
# Out:
# False

# %%
print(d==c)
# Out:
# True

# %%
# EXERCISE: try TRUE or FALSE with numbers

x1=3
x2=4
y1=5
y2=1

check=(x1+x2)==(y1+y2)
if check:
    print('Sum is equal to:', (x1+x2))
else:
    print('Error: sums not equal!')
# Out:
# Error: sums not equal!

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# #### 1.3 Numerical Operations
#
# Python has all the basic numerical operations built-in as shown below. However, the `numpy` module extends the capabilities of Pythons specifically for computing in scientific and engineering applications. We will rely heavily on the `numpy` module for this course.

# %%
# Addition
7 + 3
# Out:
# 10

# %%
# Subtraction
7 - 3
# Out:
# 4

# %%
# Multiplication
7 * 3
# Out:
# 21

# %%
# Division (floating-point division or decimal division)
7 / 3
# Out:
# 2.3333333333333335

# %%
# Quotient from floor division (integer division or truncating division)
7 // 3
# Out:
# 2

# %%
# Modulo (remainder)
7 % 3
# Out:
# 1

# %%
# Power
x ** 3
# Out:
# 125

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ## Team activity #1 (link to your team's breakout room)
#
# **Exercise 1.1**  Suppose a line passes through the following two points (4, 22) and (8, 30). Write a python code to calculate the slope ($m$) of that line and print it to the screen.
#
# *Hint:*
# \begin{equation}
# m = \frac{y_2-y_1}{x_2-x_1}
# \end{equation}

# %%
# your code here (if time in Team Activity permits)
a, b, c, d = 4, 22, 8, 30
(d-b)/(c-a)
# Out:
# 2.0

# %% [markdown]
# ### Return to main room

# %% [markdown]
# ***Let's discuss about the approach (solution strategy, how to solve it)***

# %%
# Solution

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# **Example:** Write code below that prompts the user to enter two numbers and then performs the following operations on them: addition, subtraction, multiplication, division, and modulo. Print the outputs from each of these operations.

# %%
x = float(input("Enter a number: "))
y = float(input("Enter another number: "))
# Out:
# Enter a number: 4
# Enter another number: 5

# %%
print("Addition", x + y)
print("Subtraction", x - y)
print("Multiplication", x * y)
print("Division", x / y)
print("Modulo", x % y)
# Out:
# Addition 9.0
# Subtraction -1.0
# Multiplication 20.0
# Division 0.8
# Modulo 4.0

# %% [markdown]
# #### 1.4 Logical Operations
# Just like numeric operations, Python has built-in logical operations as well, i.e., less than, greater than, equal to etc. The result of a logical operation is always a Boolean value, i.e., either `True` or `False`.

# %%
x = 3
y = 6
print(x > y)
print(y > x)
print(x == y)
print(y != x)
# Out:
# False
# True
# False
# True

# %% [markdown]
# __________________________________________________________________________________________________________________________

# %% [markdown]
# ### 2 Python libraries and modules

# %% [markdown]
# Basic numerical operations like addition, division, multiplication, etc are build-in functions as you have seen above. For more advanced mathematical operations such as logs, square roots, etc, we can import Python libraries that include such function. One such library (or module, often used interchangably) is the `math` module. However, for science and engineering applications, the library `numpy` (and `scipy` for advanced integration and optimization functions) is much more powerful. In this course, we focus almost exclusively on using `numpy`. In a a few advanced labs later in the course, we will also encounter a few functions from `scipy`, however, one can always just use `numpy` to write their own functions that perform the same calculations, which is what you will learn to also do in this course.
#
# To import a library or module, simply use the statement `import <module name>`. Say, we import a fictitious module called `applmath10py` that contains a function `lab1`, then we can call the functions or classes defined in that module by using the `.` operator, as follows, `applmath10py.lab1`. Now, if you would like to use a number of such function from `applmath10py` and quite frequently, it is wasteful to keep typing the entire module name. So, Python has a keyword `as`, which you can find in the reserved keyword list that allows you to rename the module to something shorter. So, we might write `import applmath10py as am10` and all subsequent calls to functions within the `applmath10py` module can now be called as follows, `am10.lab1`.
#
# For `numpy`, the traditional standard short name is `np`. So, we import `numpy` as follows.

# %%
import numpy as np

# %% [markdown]
# Let's now use some commonly used basic functions from `numpy`.

# %% [markdown]
# #### 2.1 Powers and Roots

# %%
# square root
x = 9
y = np.sqrt(x)
print("square root x =", y)
# Out:
# square root x = 3.0

# %%
# exponential
x = 1
y = np.exp(x)
print('e^x =' , y)
# Out:
# e^x = 2.718281828459045

# %%
# powers
x = 2
y = 3
z = np.power(x, y)
print('x^y =', z)
# Out:
# x^y = 8

# %% [markdown]
# #### 2.2 Trigonometric Functions

# %%
# sines, cosine, tangents
x = np.pi / 3
y = np.sin(x)  # the input to np.sin (and other trigonometric functions) is always assumed to be in radians
z = np.cos(x)
t1 = y / z
t2 = np.tan(x)
print('sin x =', y)
print('cos x =', z)
print('tan x =', t1, '=', t2)
# Out:
# sin x = 0.8660254037844386
# cos x = 0.5000000000000001
# tan x = 1.7320508075688767 = 1.7320508075688767

# %% [markdown]
# _________________________________________________________________________________________________

# %% [markdown]
# ## Team activity #2 (link to your team's breakout room)

# %% [markdown]
# **Exercise 2.1** This exercise has three parts. For each part, figure out what the code does and fix the errors. As the solution, write a print statement with text explaining what the code does at the end of the cell.

# %%
# Part A  

var1 = (2 * (3 + 4)) / 10
print('Variable 1 =', var1)
print("This computes a simple order of operations problem")

# %%
# Part B

a = 3
b = 4
c_user = int(input("Enter an integer: "))
c = np.sqrt(b**2 + a**2)
print(c_user == c)

# %%
# Part C

x1, y1 = 10, 20
x2, y2 = 8, 32
m = (y2 - y1) / (x2 - x1)
var2 = np.arctan(m) * 180 /np.pi
print(var2)

# %% [markdown]
# ### Return to main room

# %% [markdown]
# ***Let's discuss about the approach (solution strategy, how to solve it)***

# %%
# Part A  
# solution

# %%
# Part B
# solution

# %%
# Part C
# solution

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# ### 3. Arrays: dealing with many numbers simultaneously¶
#
# To deal with many numbers at the same time we introduce ARRAYS.
# An array is a list of numbers, either created or given to us. We can treat an array as a single object when performing different operations on it.

# %%
a=np.array([1.0,2.0,3.0,4.0])
print(a)
b=np.array([0.5,0.5,0.5,0.5])
print(b)

# %%
c=a+b
print(c)

# %%
d=2*a
print(d)

# %% [markdown]
# #### Array creation functions

# %% [markdown]
# Two `numpy` functions are commonly used to generate arrays of numbers with desired properties, namely:
#
# - `np.linspace(beginning, end, number_of_elements)` (we care about the total number of elements in the array)
#
# - `np.arange(beginning, end, step)`: produces an array within a given range and with a given step (we don't care about the number of elements in the array, whatever it takes to cover the range with the given step)

# %%
x1=np.linspace(0,5,6)
print(x1)

# %%
xmin=0
xmax=5
xstep=1.0

x2=np.arange(xmin,xmax,xstep)
print(x2)
x2

# %% [markdown]
# **Exercise 3.1**
#
# (a) Use the numpy function `linspace` to generate an array of 11 numbers (equally spaced) from -5 to 5. Print your array. How many numbers does your array contain?
#
# (b) Use the numpy function `arange` to generate an array of numbers from -5 to 5, with spacing equal to 0.5. Print your array. How many numbers does your array contain? Is the end number (number 5 in this exercise) contained in your arrays? If not, what can you do to include it?

# %%
# your code here

# %% [markdown]
# **Generate arrays filled with constant values**
#
# In many examples and problems, you'll need to initialize arrays with constant values. For example, you'll need to assign the value of 0 to all elements of an array (or the value of 1, or any other constant value); of course, these zero values will change to more meaningful values when the proper calculations will be performed.
#
# An easy way to do this initialization task is by means of the `numpy` function `np.zeros()` (you must not forget to: `import numpy as np`). For example, if you want to initialize with 0s an array named `my_array` which has N=10 elements, you can do it as `my_array = np.zeros(N)`. You will try it in the following examples and exercises.

# %%
# example:

N = 10

my_array = np.zeros(N)

print(my_array)

# %% [markdown]
# You can initialize an array with values of 1 for its elements by means of the `np.ones()` function.

# %%
# example:

my_array = np.ones(N)

print(my_array)

# %% [markdown]
# Exercise: intialize all elements of array `my_array` with the value of 3.

# %%
# your code here
